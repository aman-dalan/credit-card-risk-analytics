# %%
import pandas as pd
import numpy as np

df = pd.read_excel('CC.xlsx')

# %%
df
# Out:
#      Application id  first_name    last_name                           email  \
# 0                 1      Dollie        Scafe                   dscafe0@is.gd
# 1                 2      Austin    Pennycook             apennycook1@mac.com
# 2                 3      Mareah      Tomanek         mtomanek2@bloomberg.com
# 3                 4       Myrna  Rosenthaler          mrosenthaler3@dmoz.org
# 4                 5    Danyette       Stempe             dstempe4@tumblr.com
# ..              ...         ...          ...                             ...
# 995             996      Alvira       Gaylor         agaylorrn@webeden.co.uk
# 996             997     Frankie      O'Grada             fogradaro@bbc.co.uk
# 997             998       Rossy       Bygott  rbygottrp@networksolutions.com
# 998             999  Frederique      Blundin         fblundinrq@buzzfeed.com
# 999            1000        Mack     Eskriett             meskriettrr@mac.com
#
# ...

# %%
df['NetSalary']=df['Salary']-df['ExDebt']

# %%
df[df['NetSalary']<=0]
# Out:
#      Application id first_name  last_name                            email  \
# 219             220       Kerr     Paydon            kpaydon63@gizmodo.com
# 417             418    Lanette  Mc Gorley  lmcgorleybl@constantcontact.com
# 602             603   Charleen  Toffoloni         ctoffolonigq@latimes.com
# 888             889     Alonzo        Oak        aoakoo@simplemachines.org
#
#      gender                address  age tdecision empstaus ExCus Source  \
# 219    Male  10635 Mayfield Avenue   25   Pending      NSE     N      D
# 417  Female   408 Springview Point   30   Approve       SE     N     EC
# 602  Female      20 Forster Street   41   Pending      NSE     N      D
# 888    Male       54 Linden Center   43   Decline      NSE     Y     3P
#
#      Salary  ExDebt Booking      INT_ID      Prev_ID  \
# 219    1473    3763       Y  1626078947  33-002-3661
# 417    2110    7129       N  4447180898  35-059-5707
# 602    3323    4602       Y  5690858501  00-654-5794
# ...

# %%
df[df['NetSalary']<=0]=df[df['NetSalary']<=0].replace({"Pending":"Decline","Approve":"Decline"})

# %%
df.head()
# Out:
#    Application id first_name    last_name                    email  gender  \
# 0               1     Dollie        Scafe            dscafe0@is.gd  Female
# 1               2     Austin    Pennycook      apennycook1@mac.com    Male
# 2               3     Mareah      Tomanek  mtomanek2@bloomberg.com  Female
# 3               4      Myrna  Rosenthaler   mrosenthaler3@dmoz.org  Female
# 4               5   Danyette       Stempe      dstempe4@tumblr.com  Female
#
#                       address  age tdecision empstaus ExCus Source  Salary  \
# 0            02 Garrison Pass   34   Approve       SE     Y     EC  127110
# 1             007 Miller Road   32   Decline       SE     Y      D  464039
# 2  145 Charing Cross Junction   20   Decline       SE     Y     3P  584420
# 3             268 Algoma Hill   49   Decline       SE     Y     3P  583781
# 4       571 Stone Corner Park   36   Decline       SE     N     MP  551718
#
#    ExDebt Booking      INT_ID      Prev_ID  \
# ...

# %%
df[df['NetSalary']<=0]
# Out:
#      Application id first_name  last_name                            email  \
# 219             220       Kerr     Paydon            kpaydon63@gizmodo.com
# 417             418    Lanette  Mc Gorley  lmcgorleybl@constantcontact.com
# 602             603   Charleen  Toffoloni         ctoffolonigq@latimes.com
# 888             889     Alonzo        Oak        aoakoo@simplemachines.org
#
#      gender                address  age tdecision empstaus ExCus Source  \
# 219    Male  10635 Mayfield Avenue   25   Decline      NSE     N      D
# 417  Female   408 Springview Point   30   Decline       SE     N     EC
# 602  Female      20 Forster Street   41   Decline      NSE     N      D
# 888    Male       54 Linden Center   43   Decline      NSE     Y     3P
#
#      Salary  ExDebt Booking      INT_ID      Prev_ID  \
# 219    1473    3763       Y  1626078947  33-002-3661
# 417    2110    7129       N  4447180898  35-059-5707
# 602    3323    4602       Y  5690858501  00-654-5794
# ...

# %%
df.head()
# Out:
#    Application id first_name    last_name                    email  gender  \
# 0               1     Dollie        Scafe            dscafe0@is.gd  Female
# 1               2     Austin    Pennycook      apennycook1@mac.com    Male
# 2               3     Mareah      Tomanek  mtomanek2@bloomberg.com  Female
# 3               4      Myrna  Rosenthaler   mrosenthaler3@dmoz.org  Female
# 4               5   Danyette       Stempe      dstempe4@tumblr.com  Female
#
#                       address  age tdecision empstaus ExCus Source  Salary  \
# 0            02 Garrison Pass   34   Approve       SE     Y     EC  127110
# 1             007 Miller Road   32   Decline       SE     Y      D  464039
# 2  145 Charing Cross Junction   20   Decline       SE     Y     3P  584420
# 3             268 Algoma Hill   49   Decline       SE     Y     3P  583781
# 4       571 Stone Corner Park   36   Decline       SE     N     MP  551718
#
#    ExDebt Booking      INT_ID      Prev_ID  \
# ...

# %%
    df.loc[(df.tdecision == 'Pending'),'Booking_Amt']=' '
    df.loc[(df.tdecision=='Decline'),'Booking_Amt']=' '

# %%
df.loc[(df.tdecision == 'Pending'),'Booking']=' '
df.loc[(df.tdecision=='Decline'),'Booking']=' ' 
df.loc[(df.Booking=='N'),'Booking_Amt']=' '

# %%
df.head()
# Out:
#    Application id first_name    last_name                    email  gender  \
# 0               1     Dollie        Scafe            dscafe0@is.gd  Female
# 1               2     Austin    Pennycook      apennycook1@mac.com    Male
# 2               3     Mareah      Tomanek  mtomanek2@bloomberg.com  Female
# 3               4      Myrna  Rosenthaler   mrosenthaler3@dmoz.org  Female
# 4               5   Danyette       Stempe      dstempe4@tumblr.com  Female
#
#                       address  age tdecision empstaus ExCus Source  Salary  \
# 0            02 Garrison Pass   34   Approve       SE     Y     EC  127110
# 1             007 Miller Road   32   Decline       SE     Y      D  464039
# 2  145 Charing Cross Junction   20   Decline       SE     Y     3P  584420
# 3             268 Algoma Hill   49   Decline       SE     Y     3P  583781
# 4       571 Stone Corner Park   36   Decline       SE     N     MP  551718
#
#    ExDebt Booking      INT_ID      Prev_ID  \
# ...

# %%
df=df.drop(['Application id','first_name','last_name','email','gender','address','Source','Salary','ExDebt','INT_ID','Prev_ID','AGT_ID'],axis=1)

# %%
x=df['tdecision'].value_counts()
x
# Out:
# Decline    352
# Pending    324
# Approve    324
# Name: tdecision, dtype: int64

# %%
approval_rate=x['Approve']/x.sum()
approval_rate
# Out:
# 0.324

# %%
y=df['Booking'].value_counts()
y
# Out:
#      676
# N    175
# Y    149
# Name: Booking, dtype: int64

# %%
booking_rate=y['Y']/(y['N']+y['Y'])
booking_rate
# Out:
# 0.45987654320987653

# %%
df = pd.read_excel('Credit_cards_App_data.xlsx')

# %%
df
# Out:
#      Application id  first_name    last_name                           email  \
# 0                 1      Dollie        Scafe                   dscafe0@is.gd
# 1                 2      Austin    Pennycook             apennycook1@mac.com
# 2                 3      Mareah      Tomanek         mtomanek2@bloomberg.com
# 3                 4       Myrna  Rosenthaler          mrosenthaler3@dmoz.org
# 4                 5    Danyette       Stempe             dstempe4@tumblr.com
# ..              ...         ...          ...                             ...
# 995             996      Alvira       Gaylor         agaylorrn@webeden.co.uk
# 996             997     Frankie      O'Grada             fogradaro@bbc.co.uk
# 997             998       Rossy       Bygott  rbygottrp@networksolutions.com
# 998             999  Frederique      Blundin         fblundinrq@buzzfeed.com
# 999            1000        Mack     Eskriett             meskriettrr@mac.com
#
# ...

# %%
x=df['tdecision'].value_counts()
approval_rate=x['Approve']/x.sum()
approval_rate
# Out:
# 0.699

# %%
y=df['Booking'].value_counts()
booking_rate=y['Y']/(y['N']+y['Y'])
booking_rate
# Out:
# 0.8311874105865522

# %%
df['Net_income']=df['Salary']-df['ExDebt (Liability)']
df_new=df.drop(['Application id','first_name', 'last_name', 'email','gender','address','Salary','ExDebt (Liability)','INT_ID','Prev_ID','AGT_ID','Booking','Booking_Amt'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder() 
df_new['empstaus']= le.fit_transform(df_new['empstaus']) 
df_new['ExCus (Customer in Past)']= le.fit_transform(df_new['ExCus (Customer in Past)']) 
df_new['tdecision']= le.fit_transform(df_new['tdecision'])
df_new['Source']= le.fit_transform(df_new['Source'])

# %%
df_new = df_new[df_new.tdecision != 2]
df_new
# Out:
#      age  tdecision  empstaus  ExCus (Customer in Past)  Source  Net_income
# 1     57          0         1                         1       1      441728
# 2     57          0         1                         1       0      555863
# 3     59          0         1                         1       0      557739
# 4     51          0         1                         0       3      523826
# 5     31          0         1                         0       1      179963
# ..   ...        ...       ...                       ...     ...         ...
# 992   43          1         1                         0       0      114552
# 993   57          0         0                         0       1      443682
# 994   42          0         1                         1       2      567154
# 996   55          0         1                         0       2      449946
# 999   57          1         1                         0       1       85378
#
# [912 rows x 6 columns]

# %%
df_new.corr()
# Out:
#                                age  tdecision  empstaus  \
# age                       1.000000  -0.232888 -0.026046
# tdecision                -0.232888   1.000000  0.010537
# empstaus                 -0.026046   0.010537  1.000000
# ExCus (Customer in Past) -0.010795  -0.012958 -0.052632
# Source                    0.038154  -0.089865 -0.026345
# Net_income                0.447447  -0.755127 -0.014472
#
#                           ExCus (Customer in Past)    Source  Net_income
# age                                      -0.010795  0.038154    0.447447
# tdecision                                -0.012958 -0.089865   -0.755127
# empstaus                                 -0.052632 -0.026345   -0.014472
# ExCus (Customer in Past)                  1.000000 -0.032080   -0.021006
# Source                                   -0.032080  1.000000    0.091497
# Net_income                               -0.021006  0.091497    1.000000

# %%
x = df_new[[ 'Net_income','age','ExCus (Customer in Past)','empstaus','Source']]
y = df_new['tdecision']

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x=sc_x.fit_transform(x)
#df_new['Booking_Amt']=sc_x.fit_transform(df_new['Booking_Amt'])
#df_new['Net_income']=sc_x.fit_transform(df_new['Net_income'])

# %%
x
# Out:
# array([[ 0.86813147,  1.03527682,  1.        ,  0.99562361, -0.41327008],
#        [ 1.549707  ,  1.03527682,  1.        ,  0.99562361, -1.27377764],
#        [ 1.56090984,  1.19936657,  1.        ,  0.99562361, -1.27377764],
#        ...,
#        [ 1.61713303, -0.19539635,  1.        ,  0.99562361,  0.44723748],
#        [ 0.91720658,  0.87118706, -1.        ,  0.99562361,  0.44723748],
#        [-1.25986992,  1.03527682, -1.        ,  0.99562361, -0.41327008]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=0)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
model =LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'C':[0.00001,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]}
grid = GridSearchCV(model,parameters, cv=3)
grid=grid.fit(x_train, y_train)

# %%
grid.best_params_
# Out:
# {'C': 1000}

# %%
classifier=LogisticRegression(C=1000)
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.9817518248175182

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
model = SVC()

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'C':[0.00001,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]}
grid = GridSearchCV(model,parameters, cv=3)
grid=grid.fit(x_train, y_train)

# %%
grid.best_params_
# Out:
# {'C': 1}

# %%
classifier=SVC(C=1)
classifier.fit(x_train,y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.9781021897810219

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators':[100,150,200,250,300]}
grid = GridSearchCV(model,parameters, cv=3)
grid=grid.fit(x_train, y_train)

# %%
grid.best_params_
# Out:
# {'n_estimators': 100}

# %%
classifier=RandomForestClassifier(n_estimators=200)
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.9781021897810219

# %% [markdown]
# XGBOOST

# %%
import xgboost as xgb
xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
parameters = {"max_depth":  list(range(10)),"n_estimators":  [20,50,70,100,120,130,140,150,200]}
grid = GridSearchCV(model,parameters, cv=3)
grid=grid.fit(x_train, y_train)
# Out:
# D:\Downloads\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_depth must be greater than zero.
#
#   FitFailedWarning)
# D:\Downloads\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_depth must be greater than zero.
#
#   FitFailedWarning)
# D:\Downloads\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: max_depth must be greater than zero.
#
#   FitFailedWarning)
# ...

# %%
grid.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 50}

# %%
classifier=xgb.XGBClassifier(objective="binary:logistic", random_state=0,n_estimators=100,max_depth=5)
classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.9744525547445255
